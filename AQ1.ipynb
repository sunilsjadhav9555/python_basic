# %%
1. Given the expression a < b == c < d, what is happening here? Explain with an example.
a. a, b, c, d = 1, 2, 2, 3
b. print (a < b == c < d) # Test this code

# %%
a,b,c,d = 1,2,2,3
print(a < b == c < d)
# Out:
# True

# %%
b is greater than a and d is greater than c values is the equals to the given condition
