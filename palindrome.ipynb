# %%
Python Program to Check whether a String is Palindrome or not ?

# %%
name = input("Enter a string: ")
print(f"Your String Is = {name}")
reversed_string = name[::-1]
if name == reversed_string:
    print("String is a palindrome")
else:
    print("String is not a palindrome")
# Out:
# Enter a string:  madam
# Your String Is = madam
# String is a palindrome

# %%
Python Program to Sort Words in Alphabetic Order?

# %%
name = input ("Enter the multiple words = ")
print (f"Your String is = {name}");
word_list = name.split()
word_list.sort()
print(word_list)
# Out:
# Enter the multiple words =  x y z a b c d
# Your String is = x y z a b c d
# ['a', 'b', 'c', 'd', 'x', 'y', 'z']

# %%
Python Program to reverse a string without using inbuilt function

# %%
name = input("Enter a string: ")
print(f"Your String Is = {name}")
reversed_string = name[::-1]
print(reversed_string)
# Out:
# Enter a string:  snow
# Your String Is = snow
# wons
