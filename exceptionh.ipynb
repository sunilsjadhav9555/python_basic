# %%
if a < 3
    print('a is greater than 3')
# Out:
#   Cell In[1], line 1
#     if a < 3
#             ^
# SyntaxError: expected ':'

# %%
num1 = int(input('Please enter a number'))
print(21/num1)
# Out:
# Please enter a number 4
# 5.25

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'PythonFinalizationError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'WindowsError',
#  'ZeroDivisionError',
#  '_IncompleteInputError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'aiter',
#  'all',
#  'anext',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'breakpoint',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'execfile',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'runfile',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']

# %%
num = int(input("Enter a number: "))
print("You entered:", num)
# Out:
# Enter a number:  abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 num = int(input("Enter a number: "))
#       2 print("You entered:", num)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
try:
    num = int(input("Enter a number: "))
    print("You entered:", num)
except :
    print("Your input is wrong")
# Out:
# Enter a number:  acb
# Your input is wrong

# %%
while True:
    try:
        num = int(input("Enter a number: "))
        print("You entered:", num)
        break
    except Exception as e:
        print(e, "That’s not a valid number! Please try again.")
# Out:
# Enter a number:  asd
# invalid literal for int() with base 10: 'asd' That’s not a valid number! Please try again.
# Enter a number:  sdd
# invalid literal for int() with base 10: 'sdd' That’s not a valid number! Please try again.
# Enter a number:  23
# You entered: 23

# %%
lst = ['b', 0, 2]

for entry in lst:
    try:
        print("****************************")
        print("The entry is", entry)
        r = 1 / int(entry)
        print("The reciprocal of", entry, "is", r)
    except ValueError as ve :
        print("This is a ValueError:", ve)
    except ZeroDivisionError as ze:
        print("This is a ZeroError:", ze)
    except Exception as e:
        print("Some other error:", e)
# Out:
# ****************************
# The entry is b
# This is a ValueError: invalid literal for int() with base 10: 'b'
# ****************************
# The entry is 0
# This is a ZeroError: division by zero
# ****************************
# The entry is 2
# The reciprocal of 2 is 0.5

# %%
try:
    x = int(input("Enter a number: "))
    result = 10 / x
except ValueError:
    print("Please enter a valid number!")
except ZeroDivisionError:
    print("Cannot divide by zero!")
else:
    print("Result =", result)
# Out:
# Enter a number:  2
# Result = 5.0

# %%
try:
    
    f = open("example.txt", "w")
    
    
    f.write("Hello, this is a test.\n")
    
except OSError as e:
    
    print("File operation failed:", e)

else:
    
    print("File written successfully!")

finally:
    
    f.close()  
    print("File closed.")
# Out:
# File written successfully!
# File closed.
