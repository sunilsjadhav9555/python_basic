# %%
import math
print(math.log10(100))
# Out:
# 2.0

# %%
print(math.log10(345))
# Out:
# 2.537819095073274

# %%
print(math.py)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(math.py)
#
# AttributeError: module 'math' has no attribute 'py'

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 11, 12, 13, 43, 12, 520257)

# %%
print(math.factorial(5))
# Out:
# 120

# %%
print(math.factorial(7))
# Out:
# 5040

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
print(m.log10(345))
# Out:
# 2.537819095073274

# %%
from datetime import date
date.today()
# Out:
# datetime.date(2025, 11, 12)

# %%
from math import factorial

# %%
factorial(5)
# Out:
# 120

# %%
from math import factorial,ceil,floor

# %%
ceil(5.67)
# Out:
# 6

# %%
floor(5.67)
# Out:
# 5

# %%
from math import *
print("value of pi is" + str(pi))
