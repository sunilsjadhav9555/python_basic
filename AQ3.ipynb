# %%
3.How do you convert a string to a list and a list to a string in Python?
a. ['h', 'e', 'l', 'l', 'o']
b. Hello

# %%
name = input("Enter a string")
convert = list(name)
print(convert)
convert = ''.join(name)
print(convert)
# Out:
# Enter a string hello
# ['h', 'e', 'l', 'l', 'o']
# hello
