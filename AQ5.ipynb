# %%
5. Write a Python code to calculate the factorial of a number using a while loop

# %%
num = int(input("Enter The Number:"))

factorial = 1

i = 1

while i <= num:
    factorial *= i
    i += 1

print(f"The Factorial of number {num} is {factorial}")
# Out:
# Enter The Number: 5
# The Factorial of number 5 is 120
